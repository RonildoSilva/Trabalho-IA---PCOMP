# %% [markdown]
# ### Dataset
#
# **HDI (Human Development Index)** <br>
# Link: https://www.kaggle.com/sudhirnl7/human-development-index-hdi

# %%
import pandas as pd
import numpy as np

# %%
df_hdi = pd.read_csv('datasets/HDI.csv', index_col=0)

# %%
df_hdi.tail(14)
# Out:
#       Id                              Country  HDI Rank    HDI  \
# 181  182                          South Sudan     181.0  0.418
# 182  183                               Guinea     183.0  0.414
# 183  184                              Burundi     184.0  0.404
# 184  185                         Burkina Faso     185.0  0.402
# 185  186                                 Chad     186.0  0.396
# 186  187                                Niger     187.0  0.353
# 187  188             Central African Republic     188.0  0.352
# 188  189  Korea (Democratic People's Rep. of)       NaN    NaN
# 189  190                     Marshall Islands       NaN    NaN
# 190  191                               Monaco       NaN    NaN
# 191  192                                Nauru       NaN    NaN
# 192  193                           San Marino       NaN    NaN
# 193  194                              Somalia       NaN    NaN
# 194  195                               Tuvalu       NaN    NaN
#
#      Life expectancy  Mean years of schooling  \
# 181             56.1                      4.8
# 182             59.2                      2.6
# 183             57.1                      3.0
# 184             59.0                      1.4
# 185             51.9                      2.3
# 186             61.9                      1.7
# 187             51.5                      4.2
# 188             70.5                      NaN
# 189              NaN                      NaN
# 190              NaN                      NaN
# 191              NaN                      NaN
# 192              NaN                      NaN
# 193             55.7                      NaN
# 194              NaN                      NaN
#
#      Gross national income (GNI) per capita  \
# 181                                  1882.0
# 182                                  1058.0
# 183                                   691.0
# 184                                  1537.0
# 185                                  1991.0
# 186                                   889.0
# 187                                   587.0
# 188                                     NaN
# 189                                  4412.0
# 190                                     NaN
# 191                                 12058.0
# 192                                 50063.0
# 193                                   294.0
# 194                                  5395.0
#
#      GNI per capita rank minus HDI rank  Change in HDI rank 2010-2015  \
# 181                               -12.0                          -7.0
# 182                                 4.0                           0.0
# 183                                 5.0                          -1.0
# 184                                -8.0                           0.0
# 185                               -19.0                           0.0
# 186                                 1.0                           1.0
# 187                                 4.0                          -1.0
# 188                                 NaN                           NaN
# 189                                 NaN                           NaN
# 190                                 NaN                           NaN
# 191                                 NaN                           NaN
# 192                                 NaN                           NaN
# 193                                 NaN                           NaN
# 194                                 NaN                           NaN
#
#      Average annual HDI growth 1990-2000  ...  \
# 181                                  NaN  ...
# 182                                 1.74  ...
# 183                                -0.06  ...
# 184                                  NaN  ...
# 185                                  NaN  ...
# 186                                 1.85  ...
# 187                                -0.19  ...
# 188                                  NaN  ...
# 189                                  NaN  ...
# 190                                  NaN  ...
# 191                                  NaN  ...
# 192                                  NaN  ...
# 193                                  NaN  ...
# 194                                  NaN  ...
#
#      Coefficient of human inequality  \
# 181                              NaN
# 182                             33.6
# 183                             30.6
# 184                             33.3
# 185                             39.6
# 186                             27.5
# 187                             43.1
# 188                              NaN
# 189                              NaN
# 190                              NaN
# 191                              NaN
# 192                              NaN
# 193                              NaN
# 194                              NaN
#
#      Inequality in life expectancy (%) 2010-2015  \
# 181                                         40.7
# 182                                         35.4
# 183                                         40.8
# 184                                         37.1
# 185                                         46.2
# 186                                         35.3
# 187                                         45.7
# 188                                         15.4
# 189                                          NaN
# 190                                          NaN
# 191                                          NaN
# 192                                          NaN
# 193                                         42.1
# 194                                          NaN
#
#      Inequality-adjusted life expectancy index  Inequality in education(%)  \
# 181                                      0.330                        39.6
# 182                                      0.390                        48.3
# 183                                      0.338                        36.9
# 184                                      0.377                        38.6
# 185                                      0.264                        41.9
# 186                                      0.417                        35.0
# 187                                      0.263                        34.5
# 188                                      0.658                         NaN
# 189                                        NaN                         NaN
# 190                                        NaN                         NaN
# 191                                        NaN                         NaN
# 192                                        NaN                         NaN
# 193                                      0.318                        43.5
# 194                                        NaN                        10.5
#
#      Inequality-adjusted education index  Inequality in income (%)  \
# 181                                0.180                       NaN
# 182                                0.171                      17.1
# 183                                0.249                      14.1
# 184                                0.161                      24.2
# 185                                0.163                      30.7
# 186                                0.134                      12.3
# 187                                0.221                      49.2
# 188                                  NaN                       NaN
# 189                                  NaN                       NaN
# 190                                  NaN                       NaN
# 191                                  NaN                       NaN
# 192                                  NaN                       NaN
# 193                                  NaN                       NaN
# 194                                  NaN                       NaN
#
#      Inequality-adjusted income index  \
# 181                               NaN
# 182                             0.296
# 183                             0.251
# 184                             0.313
# 185                             0.313
# 186                             0.290
# 187                             0.136
# 188                               NaN
# 189                               NaN
# 190                               NaN
# 191                               NaN
# 192                               NaN
# 193                               NaN
# 194                               NaN
#
#      Income inequality (Quintile ratio) 2010-2015  \
# 181                                          13.1
# 182                                           5.5
# 183                                           4.8
# 184                                           5.3
# 185                                          10.0
# 186                                           5.4
# 187                                          18.3
# 188                                           NaN
# 189                                           NaN
# 190                                           NaN
# 191                                           NaN
# 192                                           NaN
# 193                                           NaN
# 194                                           7.7
#
#      Income inequality (Palma ratio) 2010-2015  \
# 181                                        2.7
# 182                                        1.3
# 183                                        1.3
# 184                                        1.5
# 185                                        2.2
# 186                                        1.4
# 187                                        4.5
# 188                                        NaN
# 189                                        NaN
# 190                                        NaN
# 191                                        NaN
# 192                                        NaN
# 193                                        NaN
# 194                                        1.9
#
#      Income inequality (Gini coefficient) 2010-2015
# 181                                            46.3
# 182                                            33.7
# 183                                            33.4
# 184                                            35.3
# 185                                            43.3
# 186                                            34.0
# 187                                            56.2
# 188                                             NaN
# 189                                             NaN
# 190                                             NaN
# 191                                             NaN
# 192                                             NaN
# 193                                             NaN
# 194                                            41.1
#
# [14 rows x 81 columns]

# %%
df_hdi = df_hdi.fillna(0)

# %%
df_hdi = df_hdi[df_hdi['HDI'] != 0]

# %%
df_hdi.shape
# Out:
# (188, 81)

# %% [markdown]
# HDI is ranked on a scale from 0 to 1.0, with 1.0 being the highest human development.
# HDI is broken down into four tiers:
#
# - very high human development (0.8-1.0)
# - high human development (0.7-0.79)
# - medium human development (0.55-.70)
# - and low human development (below 0.55)

# %%
df_hdi.insert(0, 'HDI_class', None)

# %%
df_hdi['HDI_class'] = df_hdi['HDI_class'].mask(df_hdi['HDI'] > 0.79 , 1)
df_hdi['HDI_class'] = df_hdi['HDI_class'].mask((df_hdi['HDI'] > 0.7) & (df_hdi['HDI'] <= 0.79) , 2)
df_hdi['HDI_class'] = df_hdi['HDI_class'].mask((df_hdi['HDI'] > 0.55) & (df_hdi['HDI'] <= 0.7) , 3)
df_hdi['HDI_class'] = df_hdi['HDI_class'].mask(df_hdi['HDI'] <= 0.55, 4)

# %%
df_hdi.sample(5)
# Out:
#     HDI_class   Id             Country  HDI Rank    HDI  Life expectancy  \
# 92          2   93         Saint Lucia      92.0  0.735             75.2
# 165         4  166                Togo     166.0  0.487             60.2
# 32          1   33              Cyprus      33.0  0.856             80.3
# 48          1   49  Russian Federation      49.0  0.804             70.3
# 101         2  102               Libya     102.0  0.716             71.8
#
#      Mean years of schooling  Gross national income (GNI) per capita  \
# 92                       9.3                                  9791.0
# 165                      4.7                                  1262.0
# 32                      11.7                                 29459.0
# 48                      12.0                                 23286.0
# 101                      7.3                                 14303.0
#
#      GNI per capita rank minus HDI rank  Change in HDI rank 2010-2015  ...  \
# 92                                 14.0                          -8.0  ...
# 165                                18.0                          -1.0  ...
# 32                                  4.0                          -3.0  ...
# 48                                  1.0                           5.0  ...
# 101                               -25.0                         -35.0  ...
#
#      Coefficient of human inequality  \
# 92                              15.6
# 165                             31.6
# 32                              10.8
# 48                               9.6
# 101                              0.0
#
#      Inequality in life expectancy (%) 2010-2015  \
# 92                                          10.1
# 165                                         32.4
# 32                                           4.0
# 48                                           8.8
# 101                                         15.8
#
#      Inequality-adjusted life expectancy index  Inequality in education(%)  \
# 92                                       0.763                         9.2
# 165                                      0.418                        38.9
# 32                                       0.891                        12.4
# 48                                       0.705                         2.2
# 101                                      0.671                         0.0
#
#      Inequality-adjusted education index  Inequality in income (%)  \
# 92                                 0.614                      27.4
# 165                                0.299                      23.5
# 32                                 0.688                      15.9
# 48                                 0.798                      17.7
# 101                                0.000                       0.0
#
#      Inequality-adjusted income index  \
# 92                              0.503
# 165                             0.293
# 32                              0.722
# 48                              0.678
# 101                             0.000
#
#      Income inequality (Quintile ratio) 2010-2015  \
# 92                                            0.0
# 165                                          10.7
# 32                                            5.4
# 48                                            8.2
# 101                                           0.0
#
#      Income inequality (Palma ratio) 2010-2015  \
# 92                                         0.0
# 165                                        2.6
# 32                                         1.4
# 48                                         2.0
# 101                                        0.0
#
#      Income inequality (Gini coefficient) 2010-2015
# 92                                              0.0
# 165                                            46.0
# 32                                             34.3
# 48                                             41.6
# 101                                             0.0
#
# [5 rows x 82 columns]

# %%
#df_hdi.columns

# %%
training_columns = df_hdi.columns[5:]

# %%
y_labels = df_hdi['HDI_class'].astype(int)

# %%
X = df_hdi[training_columns].values.astype(float)

# %% [markdown]
# ### Execução

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier


from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt

# %%
classifiers = [
    {'name': 'DecisionTreeClassifier', 'classifier': DecisionTreeClassifier()},
    {'name': 'MLPClassifier', 'classifier': MLPClassifier()},
    {'name': 'SGDClassifier', 'classifier': SGDClassifier()},
    {'name': 'RandomForestClassifier', 'classifier': RandomForestClassifier()}
]

# %% [markdown]
# Modelo de classificação

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_labels, test_size=0.25, random_state=42)

# %%
classifier_f1_score_data = np.array([])

for classifier in classifiers:
    
    clf = classifier['classifier'].fit(X_train, y_train)
    score = clf.score(X_test, y_test)
    y_pred = clf.predict(X_test)
    
    report = classification_report(y_test, y_pred,output_dict=True)
    f1_score = report['macro avg']['f1-score']
    
    line = [
        classifier['name'], f1_score
    ]
    
    classifier_f1_score_data = np.concatenate(
        (classifier_f1_score_data, line)
    )

# %%
classifier_f1_score_data
# Out:
# array(['DecisionTreeClassifier', 'MLPClassifier', 'SGDClassifier',
#        'RandomForestClassifier'], dtype='<U32')

# %%
# Out:
# 0.9238958209546445
